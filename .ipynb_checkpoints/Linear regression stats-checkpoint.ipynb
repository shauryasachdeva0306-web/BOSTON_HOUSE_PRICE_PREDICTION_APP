# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sbs
import plotly.express as px
from sklearn.preprocessing import StandardScaler,MinMaxScaler,LabelEncoder
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %% [markdown]
# # LINEAR REGRESSION

# %% [markdown]
# # Predict only numbers [Regression problem ko solve kr skta hai]

# %%
# prediction = m*x + c
# m=slope, c= intercept

# %%
# if i wanted to predict weight on basis of height 
# M * height + c = weight

# %%
x=[150,152,154,156,158,160,162,164,166,168]
weight=[50,52,54,56,58,60,62,64,66,68]

# %%
# training contains 70% of the data and testing includes 30% of the data

# %%
test_x= np.array([x[:3]]).reshape(3,1)
test_y= weight[:3]

# %%
train_x= np.array([x[3:]]).reshape(7,1)
train_y=weight[3:]

# %%
# MODEL

# %%
lr= LinearRegression()

# %%
lr.fit(train_x,train_y)
# Out:
# LinearRegression()

# %%
train_x
# Out:
# array([[156],
#        [158],
#        [160],
#        [162],
#        [164],
#        [166],
#        [168]])

# %%
train_y
# Out:
# [56, 58, 60, 62, 64, 66, 68]

# %%
M= lr.coef_

# %%
c= lr.intercept_

# %%
h= test_x[2]

# %%
weight=M*h+c

# %%
weight
# Out:
# array([54.])

# %%
#Regression= number prediction
#X= car purchase year 
#y= Car price

# %%
year=[2017,2018,2019,2020,2021,2022,2023,2024,2025,2026]
price=[520000,540000,560000,580000,600000,620000,640000,660000,680000,700000]

# %%
lr=LinearRegression()

# %%
lr.fit(train_x,train_y)
# Out:
# LinearRegression()

# %%
m=lr.coef_

# %%
h= test_x[2]

# %%
c= lr.intercept_

# %%
price=m*h+c

# %%
price
# Out:
# array([560000.])
